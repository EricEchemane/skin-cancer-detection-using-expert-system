# %% [markdown]
# # Skin or Not Skin Classifier Model

# %%
train_data_directory = 'dataset/train'
test_data_directory = 'dataset/test'

# %%
import cv2 # open cv
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

load_model = tf.keras.models.load_model
image = tf.keras.preprocessing.image
ImageDataGenerator = tf.keras.preprocessing.image.ImageDataGenerator
Sequential = tf.keras.models.Sequential
Dense = tf.keras.layers.Dense
Activation = tf.keras.layers.Activation
Flatten = tf.keras.layers.Flatten
Conv2D = tf.keras.layers.Conv2D
MaxPooling2D = tf.keras.layers.MaxPooling2D

# %%
# initiate data preprocessing tools

# This step processes the images into a format that
# 1. makes the data readable to the model
# 2. provides more training material for the model to train from
# the `training_data_processor` below scales the data so that it can be
# a model input, but also takes each image and augments it so that
# the model can learn from multiple variations of the same image.
# it flips it horizontally, rotates it, shifts it, and more so that 
# the model learns from the soil photo rather than the orientation size
training_data_processor  = ImageDataGenerator(
    rescale = 1./255,
    horizontal_flip = True,
    zoom_range = 0.2,
    rotation_range = 10,
    shear_range = 0.2,
    height_shift_range = 0.1,
    width_shift_range = 0.1,
)
# for the testing images, we don't need to create multiple variatinos
test_data_processor = ImageDataGenerator(rescale=1./255)


# load data into python

training_data = training_data_processor.flow_from_directory(
    train_data_directory,
    target_size = (256, 256), # pixels
    batch_size = 32,
    class_mode = 'categorical',
)

testing_data = test_data_processor.flow_from_directory(
    test_data_directory,
    target_size = (256, 256),
    batch_size = 32,
    class_mode = 'categorical',
    shuffle = False
)
# Out:
# Found 1200 images belonging to 2 classes.
# Found 120 images belonging to 2 classes.

# %% [markdown]
# ## Model building

# %%
# choose model parameters
num_conv_layers = 3
num_dense_layers = 2
layer_size = 29 # limit the layer size as we dont want to over fit the model
num_training_epochs = 50
MODEL_NAME = 'skin_or_not_model'

CLASSES = ['not_skin', 'skin']

# %%
# initiate model variable
model = Sequential()

# begin adding properties to model variable
# e.g. add a convulutional layer
model.add(Conv2D(layer_size, (3,3), input_shape=(256, 256, 3)))
model.add(Activation('relu')) # rectified linear unit
model.add(MaxPooling2D(pool_size=(2,2)))

# add additional convolutional layers based on num_conv_layers
for _ in range(num_conv_layers-1):
    model.add(Conv2D(layer_size, (3,3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))

# reduce dimensionality
model.add(Flatten())

# add fully connected "dense" layers if specified
for _ in range(num_dense_layers):
    model.add(Dense(layer_size))
    model.add(Activation('relu'))

# output layer
model.add(Dense(len(CLASSES)))
model.add(Activation('softmax'))

# compile the sequential model with all added properties
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy'])

# use the data already loaded to train/tune the model
model_results = model.fit(
    training_data,
    epochs = num_training_epochs, 
    validation_data = testing_data)

# save the trained model
model.save(f'{MODEL_NAME}.h5')
# Out:
# Epoch 1/50
# 38/38 [==============================] - 42s 1s/step - loss: 0.4473 - accuracy: 0.8025 - val_loss: 0.1129 - val_accuracy: 0.9750
# Epoch 2/50
# 38/38 [==============================] - 37s 960ms/step - loss: 0.0933 - accuracy: 0.9675 - val_loss: 0.0431 - val_accuracy: 0.9750
# Epoch 3/50
# 38/38 [==============================] - 37s 968ms/step - loss: 0.0565 - accuracy: 0.9850 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 4/50
# 38/38 [==============================] - 39s 1s/step - loss: 0.0442 - accuracy: 0.9900 - val_loss: 0.0125 - val_accuracy: 0.9917
# Epoch 5/50
# 38/38 [==============================] - 36s 953ms/step - loss: 0.2264 - accuracy: 0.9367 - val_loss: 0.0265 - val_accuracy: 0.9833
# Epoch 6/50
# 38/38 [==============================] - 37s 956ms/step - loss: 0.1104 - accuracy: 0.9675 - val_loss: 0.6075 - val_accuracy: 0.7917
# Epoch 7/50
# 38/38 [==============================] - 38s 981ms/step - loss: 0.0900 - accuracy: 0.9742 - val_loss: 0.0080 - val_accuracy: 0.9917
# Epoch 8/50
# 38/38 [==============================] - 37s 953ms/step - loss: 0.0773 - accuracy: 0.9808 - val_loss: 0.0229 - val_accuracy: 0.9917
# Epoch 9/50
# 38/38 [==============================] - 37s 959ms/step - loss: 0.0897 - accuracy: 0.9733 - val_loss: 0.0918 - val_accuracy: 0.9833
# Epoch 10/50
# 38/38 [==============================] - 37s 954ms/step - loss: 0.0550 - accuracy: 0.9833 - val_loss: 0.0158 - val_accuracy: 0.9917
# Epoch 11/50
# 38/38 [==============================] - 37s 978ms/step - loss: 0.0393 - accuracy: 0.9908 - val_loss: 0.0164 - val_accuracy: 0.9917
# Epoch 12/50
# 38/38 [==============================] - 37s 958ms/step - loss: 0.0493 - accuracy: 0.9850 - val_loss: 0.0334 - val_accuracy: 0.9833
# Epoch 13/50
# 38/38 [==============================] - 37s 959ms/step - loss: 0.0512 - accuracy: 0.9842 - val_loss: 0.0635 - val_accuracy: 0.9833
# Epoch 14/50
# 38/38 [==============================] - 37s 963ms/step - loss: 0.0354 - accuracy: 0.9900 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 15/50
# 38/38 [==============================] - 37s 959ms/step - loss: 0.0594 - accuracy: 0.9783 - val_loss: 0.0309 - val_accuracy: 0.9917
# Epoch 16/50
# 38/38 [==============================] - 37s 959ms/step - loss: 0.0395 - accuracy: 0.9883 - val_loss: 0.0194 - val_accuracy: 0.9917
# Epoch 17/50
# 38/38 [==============================] - 38s 989ms/step - loss: 0.0370 - accuracy: 0.9883 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 18/50
# 38/38 [==============================] - 38s 978ms/step - loss: 0.0377 - accuracy: 0.9867 - val_loss: 0.0409 - val_accuracy: 0.9833
# Epoch 19/50
# 38/38 [==============================] - 38s 984ms/step - loss: 0.0459 - accuracy: 0.9842 - val_loss: 0.0125 - val_accuracy: 0.9917
# Epoch 20/50
# 38/38 [==============================] - 37s 979ms/step - loss: 0.0266 - accuracy: 0.9933 - val_loss: 0.0147 - val_accuracy: 0.9917
# Epoch 21/50
# 38/38 [==============================] - 37s 963ms/step - loss: 0.0297 - accuracy: 0.9917 - val_loss: 0.0101 - val_accuracy: 0.9917
# Epoch 22/50
# 38/38 [==============================] - 37s 959ms/step - loss: 0.0258 - accuracy: 0.9925 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 23/50
# 38/38 [==============================] - 37s 960ms/step - loss: 0.0623 - accuracy: 0.9775 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 24/50
# 38/38 [==============================] - 43s 1s/step - loss: 0.0457 - accuracy: 0.9850 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 25/50
# 38/38 [==============================] - 45s 1s/step - loss: 0.0334 - accuracy: 0.9875 - val_loss: 0.0131 - val_accuracy: 0.9917
# Epoch 26/50
# 38/38 [==============================] - 38s 992ms/step - loss: 0.0213 - accuracy: 0.9950 - val_loss: 0.0294 - val_accuracy: 0.9917
# Epoch 27/50
# 38/38 [==============================] - 37s 958ms/step - loss: 0.0315 - accuracy: 0.9892 - val_loss: 0.0460 - val_accuracy: 0.9833
# Epoch 28/50
# 38/38 [==============================] - 37s 963ms/step - loss: 0.0422 - accuracy: 0.9883 - val_loss: 0.0134 - val_accuracy: 0.9917
# Epoch 29/50
# 38/38 [==============================] - 37s 958ms/step - loss: 0.0232 - accuracy: 0.9925 - val_loss: 0.
- val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 49/50
# 38/38 [==============================] - 38s 993ms/step - loss: 0.0307 - accuracy: 0.9892 - val_loss: 0.0141 - val_accuracy: 0.9917
# Epoch 50/50
# 38/38 [==============================] - 37s 977ms/step - loss: 0.0886 - accuracy: 0.9825 - val_loss: 0.0161 - val_accuracy: 0.9917

# %% [markdown]
# ## Model Summary

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 29)      812
#
#  activation (Activation)     (None, 254, 254, 29)      0
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 29)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 29)      7598
#
#  activation_1 (Activation)   (None, 125, 125, 29)      0
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 29)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 29)        7598
#
#  activation_2 (Activation)   (None, 60, 60, 29)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 29)       0
#  2D)
#
#  flatten (Flatten)           (None, 26100)             0
#
#  dense (Dense)               (None, 29)                756929
#
#  activation_3 (Activation)   (None, 29)                0
#
#  dense_1 (Dense)             (None, 29)                870
#
#  activation_4 (Activation)   (None, 29)                0
#
#  dense_2 (Dense)             (None, 2)                 60
#
#  activation_5 (Activation)   (None, 2)                 0
#
# =================================================================
# Total params: 773,867
# Trainable params: 773,867
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Evaluation

# %%
test_result = model.evaluate(testing_data)

print(test_result)
# Out:
# 4/4 [==============================] - 1s 194ms/step - loss: 0.0161 - accuracy: 0.9917
# [0.016054848209023476, 0.9916666746139526]

# %%
import pandas as pd

training_dataframe = pd.DataFrame(model_results.history)
plt.plot(training_dataframe['accuracy'], label='Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# %%
y_predicted = model.predict(testing_data)
y_predicted = [x.argmax() for x in y_predicted]

from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(testing_data.classes, y_predicted)

import seaborn as sb

sb.heatmap(matrix, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# 4/4 [==============================] - 1s 179ms/step
# Text(50.722222222222214, 0.5, 'Truth')

# %%
def classify(image_fp):
    im = cv2.imread(image_fp) # load the image from the given file path (image_fp)
    plt.imshow(im[:,:,[2,1,0]]) # swap the colors because open-cv swaps the rgb colors
    img = image.load_img(image_fp, target_size = (256, 256))
    img = image.img_to_array(img)

    image_array = img / 255. # scale the image
    img_batch = np.expand_dims(image_array, axis = 0)

    class_ = CLASSES # possible output values
    from tensorflow import keras
    model = keras.models.load_model(f'{MODEL_NAME}.h5')
    predicted_value = model.predict(img_batch)
    
    out  = f"""
     not_skin: {predicted_value[0][0]:.5f}
         skin: {predicted_value[0][1]:.5f}

    Result: {(predicted_value[0][predicted_value.argmax()] * 100):.2f}% {class_[predicted_value.argmax()]}

    """
  # accuracy: {(accuracy[1]*100):.5f}
  #     loss: {(accuracy[0]*100):.5f}
    return out

# %%
test_image_file_path = test_data_directory + '/not_skin/IMG_20220505_191812.jpg'
test_prediction = classify(test_image_file_path)

print(test_prediction)
# Out:
# 1/1 [==============================] - 0s 70ms/step
#
#      not_skin: 1.00000
#          skin: 0.00000
#
#     Result: 100.00% not_skin

# %% [markdown]
# ## Convert final_model.h5 to TFLITE

# %%
import tensorflow as tf

model = tf.keras.models.load_model(f'{MODEL_NAME}.h5')
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
open("final_model.tflite", "wb").write(tflite_model)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\ERICEC~1\AppData\Local\Temp\tmpvl1_2czm\assets
# INFO:tensorflow:Assets written to: C:\Users\ERICEC~1\AppData\Local\Temp\tmpvl1_2czm\assets
# 3099920

# %% [markdown]
# ## Converting to tfjs

# %%
import os
os.system(f"""
tensorflowjs_converter --input_format keras \
	{MODEL_NAME}.h5 \
	tfjs""")
# Out:
# 0
